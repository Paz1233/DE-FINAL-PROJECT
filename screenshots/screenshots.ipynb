# %% [markdown]
# ## Raw Check In

# %%
from IPython.display import Image

Image("./bronze/raw_check_in.png")

# %% [markdown]
# ## Raw Coin Change

# %%
Image("./bronze/raw_coin_change.png")

# %% [markdown]
# ## Raw Flight Booking

# %%
Image("./bronze/raw_flight_booking.png")

# %% [markdown]
# ## Raw Flight Schedule

# %%
Image("./bronze/raw_flight_schedule.png")

# %% [markdown]
# ## Raw Flights

# %%
Image("./bronze/raw_flights.png")

# %% [markdown]
# ## Raw Payments

# %%
Image("./bronze/raw_payments.png")

# %% [markdown]
# ## Raw Updates

# %%
Image("./bronze/raw_updates.png")

# %% [markdown]
# ## Silver Check In

# %%
Image("./silver/silver_check_in.png")

# %% [markdown]
# ## Silver Coin Change

# %%
Image("./silver/silver_coin_change.png")

# %% [markdown]
# ## Silver Flight Booking

# %%
Image("./silver/silver_flight_booking.png")

# %% [markdown]
# ## Silver Flight Schedule

# %%
Image("./silver/silver_flight_schedule.png")

# %% [markdown]
# ## Silver Flights

# %%
Image("./silver/silver_flights.png")

# %% [markdown]
# ## Silver Payments

# %%
Image("./silver/silver_payments.png")

# %% [markdown]
# ## Silver Updates

# %%
Image("./silver/silver_updates.png")

# %% [markdown]
# ## Gold Booking

# %% [markdown]
# <div style="display: flex; justify-content: space-around;">
#   <img src="./gold/gold_booking_1.png" width="75%" />
#   <img src="./gold/gold_booking_2.png" width="25%" />
# </div>

# %% [markdown]
# ## Gold Flights

# %% [markdown]
# <div style="display: flex; justify-content: space-around;">
#   <img src="./gold/gold_flights.png" width="75%" />
#   <img src="./gold/gold_flights_1.png" width="25%" />
# </div>

# %% [markdown]
# ## Gold Coin Change

# %%
Image("./gold/gold_coin_change.png")

# %% [markdown]
# ## Gold Payments

# %%
Image("./gold/gold_payments.png")

# %% [markdown]
# ## Gold Updates

# %%
Image("./gold/gold_updates.png")
